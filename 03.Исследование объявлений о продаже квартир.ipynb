# %% [markdown]
# <div style="border:solid green 3px; padding: 20px">
#
# <b>Привет!</b>
#
# Меня зовут Сороколетов Илья и я буду проверять твой проект.
#
# Предлагаю общаться на «**ты**», но если тебе будет комфортнее общаться на «**вы**», то сообщи об этом в комментариях)
#
#
# Для твоего удобства, я буду выделять свои комментарии следующим образом:
#
# <div class="alert alert-danger">
# <b>❌ Комментарий ревьюера v1:</b> Самые важные замечания. Они указывают на ключевые моменты, которые влияют на конечный результат проекта. </div>
#
# <div class="alert alert-warning">
# <b>⚠️ Комментарий ревьюера v1:</b> Советы или замечания, которые помогут сделать твою работу лучше, но необязательны к выполнению.
#
# </div>
#
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v1:</b> Так я выделяю все остальные комментарии.</div>
#
#
# Пометками <b>v1-v2-v3-...</b> я буду отмечать версию проверки. Так ты сможешь быстро найти мои новые комментарии.
#
# Давай работать над проектом в диалоге: если ты что-то меняешь в проекте по моим рекомендациям — пиши об этом. Выбери для своих комментариев какой-то заметный цвет, так мне будет легче отследить изменения, например вот так:
#
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br>
# </div>
#
# <b>Пожалуйста, не перемещай, не изменяй и не удаляй мои комментарии.</b> Если ты оставляешь свои комментарии, то делай это под моими, чтобы сообщения были расположены в хронологическом порядке. Всё это поможет выполнить повторную проверку твоего проекта быстрее.
#
# Перед отправкой работы я рекомендую нажимать Kernel -> Restart & Run All. Это перезапустит ядро и по очереди выполнит все ячейки. Так ты сможешь проверить, что всё работает корректно. Кнопка Kernel находится в панели сверху
#
# Обязательно задавай вопросы если они возникнут, а я перехожу к проверке)
#
# P.S. На всякий случай, я оставлю пустой шаблон для твоих комментариев ниже. Кликни два раза на мой комментарий, скопируй последние четыре строчки кода и вставляй их в пустую ячейку там, где ты хочешь оставить комментарий. Не забудь только перед этим сменить тип ячейки на Markdown. Быстро это можно сделать так: кликнуть на ячейку - нажать ESC - нажать M.
#
#
# <div class="alert alert-info">
# <b>Комментарий студента:</b>
# <br>Удали этот текст и вместо него напиши свой комментарий 🙂
# </div>

# %% [markdown]
# <div class="alert alert-info"> Привет! Извиняюсь за опоздание. Ввиду своих временных ограничений в этот раз, проект у меня получился немного простоват и даже сыроват. Надеюсь на вашу помощь в виде замечаний и советов! </div>

# %% [markdown]
# <div class="alert alert-danger">
# <b>❌ Комментарий ревьюера:</b>
# <br>Перед отправкой проекта обязательно перезапускай ядро через Kernel -> Restart & Run All и проверяй, чтобы все ячейки отработали без ошибок. 9 ячейка сейчас падает с ошибкой. Поправь, пожалуйста, чтобы я смог проверить твой проект
# </div>

# %% [markdown]
# <div class="alert alert-info"> Сделано. У меня датасет был локально вызван. </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v1:</b>
# <br>Теперь всё работает) Перехожу к проверке!
# </div>

# %% [markdown]
# # Исследование объявлений о продаже квартир
#
# В вашем распоряжении данные сервиса Яндекс.Недвижимость — архив объявлений о продаже квартир в Санкт-Петербурге и соседних населённых пунктов за несколько лет. Нужно научиться определять рыночную стоимость объектов недвижимости. Ваша задача — установить параметры. Это позволит построить автоматизированную систему: она отследит аномалии и мошенническую деятельность.
#
# По каждой квартире на продажу доступны два вида данных. Первые вписаны пользователем, вторые — получены автоматически на основе картографических данных. Например, расстояние до центра, аэропорта, ближайшего парка и водоёма.

# %% [markdown]
# ### Описание данных
# - `airports_nearest` — расстояние до ближайшего аэропорта в метрах (м)
# - `balcony` — число балконов
# - `ceiling_height` — высота потолков (м)
# - `cityCenters_nearest` — расстояние до центра города (м)
# - `days_exposition` — сколько дней было размещено объявление (от публикации до снятия)
# - `first_day_exposition` — дата публикации
# - `floor` — этаж
# - `floors_total` — всего этажей в доме
# - `is_apartment` — апартаменты (булев тип)
# - `kitchen_area` — площадь кухни в квадратных метрах (м²)
# - `last_price` — цена на момент снятия с публикации
# - `living_area` — жилая площадь в квадратных метрах (м²)
# - `locality_name` — название населённого пункта
# - `open_plan` — свободная планировка (булев тип)
# - `parks_around3000` — число парков в радиусе 3 км
# - `parks_nearest` — расстояние до ближайшего парка (м)
# - `ponds_around3000` — число водоёмов в радиусе 3 км
# - `ponds_nearest` — расстояние до ближайшего водоёма (м)
# - `rooms` — число комнат
# - `studio` — квартира-студия (булев тип)
# - `total_area` — общая площадь квартиры в квадратных метрах (м²)
# - `total_images` — число фотографий квартиры в объявлении

# %% [markdown]
# ### Откройте файл с данными и изучите общую информацию.

# %%
import math
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
pd.set_option('display.max_columns', None)
import seaborn as sns
import numpy as np
pd.options.display.float_format = '{:.2f}'.format
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('/datasets/real_estate_data.csv', sep='\t')
#data = pd.DataFrame(data, columns=data.columns)
data = data.reset_index(level=0)
data = data.rename(columns={'index': 'id'})

# %%
data.info()
data.head(15)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 23 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    23699 non-null  int64
#  1   total_images          23699 non-null  int64
#  2   last_price            23699 non-null  float64
#  3   total_area            23699 non-null  float64
#  4   first_day_exposition  23699 non-null  object
#  5   rooms                 23699 non-null  int64
#  6   ceiling_height        14504 non-null  float64
#  7   floors_total          23613 non-null  float64
#  8   living_area           21796 non-null  float64
#  9   floor                 23699 non-null  int64
#  10  is_apartment          2775 non-null   object
#  11  studio                23699 non-null  bool
#  12  open_plan             23699 non-null  bool
#  13  kitchen_area          21421 non-null  float64
#  14  balcony               12180 non-null  float64
# ...

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v1:</b>
# <br>Отлично, что ты увеличиваешь лимит для отображаемых столбцов, чтобы было видно всю таблицу
# </div>

# %%
data.describe()
# Out:
#             id  total_images   last_price  total_area    rooms  \
# count 23699.00      23699.00     23699.00    23699.00 23699.00
# mean  11849.00          9.86   6541548.77       60.35     2.07
# std    6841.46          5.68  10887013.27       35.65     1.08
# min       0.00          0.00     12190.00       12.00     0.00
# 25%    5924.50          6.00   3400000.00       40.00     1.00
# 50%   11849.00          9.00   4650000.00       52.00     2.00
# 75%   17773.50         14.00   6800000.00       69.90     3.00
# max   23698.00         50.00 763000000.00      900.00    19.00
#
#        ceiling_height  floors_total  living_area    floor  kitchen_area  \
# count        14504.00      23613.00     21796.00 23699.00      21421.00
# mean             2.77         10.67        34.46     5.89         10.57
# std              1.26          6.60        22.03     4.89          5.91
# min              1.00          1.00         2.00     1.00          1.30
# ...

# %%
data.hist(bins=50, figsize=(15,20))
plt.show()

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v1:</b>
# <br>Графики построено верно!
# </div>

# %% [markdown]
# <div class="alert alert-warning">
# <b>⚠️ Комментарий ревьюера v1:</b>
# <br>Здесь необходимо написать короткий вывод о проблемах с данными (пропуски, дубликаты, неверный тип данных, странные значения и т.д.). Вижу, что ты пишешь его ниже, но лучше каждый раздел заканчивать кратким выводом
# </div>

# %% [markdown]
# ### Предобработка данных

# %%
data = data.rename(columns={
    'cityCenters_nearest': 'city_centers_nearest'}) # переименование столбцов
data.columns

#на мой взгляд этот столбец единственный выбивался из толпы.
# Out:
# Index(['id', 'total_images', 'last_price', 'total_area',
#        'first_day_exposition', 'rooms', 'ceiling_height', 'floors_total',
#        'living_area', 'floor', 'is_apartment', 'studio', 'open_plan',
#        'kitchen_area', 'balcony', 'locality_name', 'airports_nearest',
#        'city_centers_nearest', 'parks_around3000', 'parks_nearest',
#        'ponds_around3000', 'ponds_nearest', 'days_exposition'],
#       dtype='object')

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v1:</b>
# <br>Молодец! Так датафрейм будет более аккуратным
# </div>

# %%
#выводим кол-во пропусков
data.isna().sum()
# Out:
# id                          0
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height           9195
# floors_total               86
# living_area              1903
# floor                       0
# is_apartment            20924
# studio                      0
# open_plan                   0
# kitchen_area             2278
# balcony                 11519
# locality_name              49
# airports_nearest         5542
# city_centers_nearest     5519
# parks_around3000         5518
# parks_nearest           15620
# ponds_around3000         5518
# ponds_nearest           14589
# days_exposition          3181
# dtype: int64

# %%
#выводим их процентное соотношение к датасету и сортируем для наглядности
data.isna().sum().sort_values()/data.shape[0]*100
# Out:
# id                      0.00
# open_plan               0.00
# floor                   0.00
# rooms                   0.00
# studio                  0.00
# total_area              0.00
# last_price              0.00
# first_day_exposition    0.00
# total_images            0.00
# locality_name           0.21
# floors_total            0.36
# living_area             8.03
# kitchen_area            9.61
# days_exposition        13.42
# parks_around3000       23.28
# ponds_around3000       23.28
# city_centers_nearest   23.29
# airports_nearest       23.38
# ceiling_height         38.80
# balcony                48.61
# ponds_nearest          61.56
# parks_nearest          65.91
# is_apartment           88.29
# dtype: float64

# %% [markdown]
# Мы видим, что пропущенных значений довольно много.
#
# Столбцы (`parks_around3000`, `parks_nearest`, `ponds_around3000`, `ponds_nearest`, `cityCenters_nearest`, `airports_nearest`) могли быть сочтены неважными для заполнения, а может у людей и не было подобной информации (и лень было её искать). В любом случае мы не располагаем достаточными данными для заполнения этих столбцов.
#
# `locality_name` сильно выбивается, возможно людям показалось настолько очевидным то, где они продают квартиру, что решили не заполнять. Тут тоже за неимением картографических данных, пробелы пока оставим.
#
# `cityCenters_nearest` - ~здесь может быть та же причина, что и для `locality_name`, возможно квартира уже находися в центре или около центра, и люди не стали заморачиваться.~ Возможно людям за городом в принципе не интересно
#
# Остальные пробелы больше похожи на случайные и мы их будем пытаться заполнять по ходу дела.

# %%
data.query('locality_name == "Санкт_Петербург" and city_centers_nearest.isna()')
# Out:
# Empty DataFrame
# Columns: [id, total_images, last_price, total_area, first_day_exposition, rooms, ceiling_height, floors_total, living_area, floor, is_apartment, studio, open_plan, kitchen_area, balcony, locality_name, airports_nearest, city_centers_nearest, parks_around3000, parks_nearest, ponds_around3000, ponds_nearest, days_exposition]
# Index: []

# %%
data[data['city_centers_nearest'].isna() == True]
# Out:
#           id  total_images  last_price  total_area first_day_exposition  \
# 5          5            10  2890000.00       30.40  2018-09-10T00:00:00
# 8          8            20  2900000.00       33.16  2018-05-23T00:00:00
# 12        12            10  3890000.00       54.00  2016-06-30T00:00:00
# 22        22            20  5000000.00       58.00  2017-04-24T00:00:00
# 30        30            12  2200000.00       32.80  2018-02-19T00:00:00
# ...      ...           ...         ...         ...                  ...
# 23683  23683            16  2100000.00       62.80  2018-09-18T00:00:00
# 23692  23692             2  1350000.00       30.00  2017-07-07T00:00:00
# 23695  23695            14  3100000.00       59.00  2018-01-15T00:00:00
# 23696  23696            18  2500000.00       56.70  2018-02-11T00:00:00
# 23698  23698             4  1350000.00       32.30  2017-07-21T00:00:00
#
#        rooms  ceiling_height  floors_total  living_area  floor is_apartment  \
# ...

# %% [markdown]
# `ceiling_height` - почти 40% данных отсутсвуют. Предварительно предположу, что присутствует человеческий фактор. Возможно почти половина людей просто поленились измерять потолки. Заполнять 40% пропусков медианой - довольно рискованно в целом, но в этом случае мы можем довольно смело предположить, что большая часть домов сделана по городскому стандарту. Поэтому пока что применим медиану. Boxplot-м ниже будет видно, что среднее не подойдет из-за больших разбросов.

# %%
data.boxplot(column='ceiling_height', return_type='axes', figsize=(10,10))
plt.show()

# %%
data['ceiling_height'].median() #проверяем медианное значение столбца
# Out:
# 2.65

# %%
#заполяем пропуски медианным значением, так как 2.7 метра - вполне себе хорошая медиана
data['ceiling_height'] = data['ceiling_height'].fillna(data['ceiling_height'].median())

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v1:</b>
# <br>Согласен с таким решением, так как основная часть данных в этом столбце находится в небольшом диапазоне.
# </div>

# %% [markdown]
# `floors_total/balcony` - данные могут отсутствать по причине необязательности заполнения этих столбцов. В случае с балконами могут отсутствовать балконы

# %%
#поэтому просто заполняем нулями
data['balcony'] = data['balcony'].fillna(0.)

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v1:</b>
# <br>👌
# </div>

# %% [markdown]
# `floors_total` я решил заполнить пропуски путем назначения указаного этажа как максимального. Ибо выяснилось, что в подобных объявлениях всё-таки присутствуют значения `floor`, и меньше этого значения пробелы заполнять было бы немного глупо. Значения всё равно арбитральные, но на выборку это не повлияет из-за сильно малого количества пропусков. Заполнять изначально не хотел, но потом появилось желание перевести тип значения в int64.

# %%
data.query('floors_total.isna()')[['floors_total', 'floor']]
# Out:
#        floors_total  floor
# 186             NaN      4
# 237             NaN      1
# 457             NaN     12
# 671             NaN      8
# 1757            NaN      9
# ...             ...    ...
# 22542           NaN      3
# 22656           NaN     20
# 22808           NaN      6
# 23590           NaN     18
# 23658           NaN      8
#
# [86 rows x 2 columns]

# %%
data['floors_total'] = data['floors_total'].fillna(data['floor'])

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v1:</b>
# <br>Хороший способ)
# </div>

# %%
data.query('id == [186, 1757, 23658]')[['floors_total', 'floor']] #ручная выборка по индексу для проверки
# Out:
#        floors_total  floor
# 186            4.00      4
# 1757           9.00      9
# 23658          8.00      8

# %%
data.isna().sum()
# Out:
# id                          0
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height              0
# floors_total                0
# living_area              1903
# floor                       0
# is_apartment            20924
# studio                      0
# open_plan                   0
# kitchen_area             2278
# balcony                     0
# locality_name              49
# airports_nearest         5542
# city_centers_nearest     5519
# parks_around3000         5518
# parks_nearest           15620
# ponds_around3000         5518
# ponds_nearest           14589
# days_exposition          3181
# dtype: int64

# %% [markdown]
# `kitchen_area/living_area` - данные, которые могут быть не заполнены просто по той причине, что они необязательны к заполнению, а высчитывать жилую площадь/площадь кухни продавцам некогда.

# %% [markdown]
# По поводу `kitchen_area` и `living_area` сначла хотелось бы проверить их отношение к квартирам студийного типа

# %%
data.groupby('rooms')[['kitchen_area', 'living_area', 'studio']].sum()
# Out:
#        kitchen_area  living_area  studio
# rooms
# 0              0.00      3452.34     138
# 1          68885.00    132197.56      11
# 2          72711.25    231552.05       0
# 3          60840.16    254283.69       0
# 4          14770.82     72944.73       0
# 5           5234.78     29202.70       0
# 6           2041.73     12967.38       0
# 7           1143.90      8668.90       0
# 8            223.80      2024.20       0
# 9            175.50      1331.80       0
# 10            68.60       496.70       0
# 11            25.20       267.80       0
# 12           112.00       409.70       0
# 14            42.50       390.30       0
# 15           100.00       409.00       0
# 16            13.00       180.00       0
# 19            27.60       264.50       0

# %%
data['studio'].value_counts() #проверяем кол-во студий
# Out:
# False    23550
# True       149
# Name: studio, dtype: int64

# %%
data.query('studio == True')[['kitchen_area', 'living_area']].isna().sum() #смотрим кол-во пропусков
# Out:
# kitchen_area    149
# living_area      10
# dtype: int64

# %% [markdown]
# Довольно маленькая выборка. Эти значения можно было бы заполнить нулем, так как в планировке квартир студийного типа может не указываться наличие кухни, но в целом большой роли это не сыграет.

# %%
data['kitchen_area'].isna().sum()
# Out:
# 2278

# %% [markdown]
# Что касается `living_area` в целом, пропуски тут можно заполнить поделив общую площадь на коэффициент средних показателей общей площади и средних показателей жилой площади.

# %%
data.query('kitchen_area + living_area > total_area') #проверка на аномалии (упс)
# Out:
#           id  total_images  last_price  total_area first_day_exposition  \
# 184      184             7  2600000.00       30.20  2018-02-14T00:00:00
# 545      545             9  4700000.00       23.80  2018-12-28T00:00:00
# 551      551             8  3100000.00       31.59  2018-03-08T00:00:00
# 601      601            12  5600000.00       53.70  2017-04-18T00:00:00
# 696      696             1  3364930.00       34.69  2014-11-27T00:00:00
# ...      ...           ...         ...         ...                  ...
# 21824  21824            20  2450000.00       44.00  2019-02-12T00:00:00
# 21868  21868            12  2600000.00       34.30  2018-09-26T00:00:00
# 21915  21915            14 11990000.00       91.40  2016-05-16T00:00:00
# 21956  21956             0  5200000.00       46.00  2018-07-20T00:00:00
# 23202  23202            13  4919880.00       67.92  2018-10-23T00:00:00
#
#        rooms  ceiling_height  floors_total  living_area  floor is_apartment  \
# ...

# %%
data.isna().sum()
# Out:
# id                          0
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height              0
# floors_total                0
# living_area              1903
# floor                       0
# is_apartment            20924
# studio                      0
# open_plan                   0
# kitchen_area             2278
# balcony                     0
# locality_name              49
# airports_nearest         5542
# city_centers_nearest     5519
# parks_around3000         5518
# parks_nearest           15620
# ponds_around3000         5518
# ponds_nearest           14589
# days_exposition          3181
# dtype: int64

# %%
#Сначала коэффициент соотношения средней общей площади (там где она есть .isna() == False) к среднему жилой площади:
 
total_living_coef = data[data['living_area'].isna() == False]['total_area'].mean() / data[data['living_area'].isna()== False]['living_area'].mean() 
 
#Заполним пропуски отношением общей площади на коэффициент
data['living_area'] = data['living_area'].fillna(data['total_area']/total_living_coef)

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v1:</b>
# <br>Прекрасный способ для замены! 👏🏻👏🏻👏🏻
# </div>

# %%
data[(data['kitchen_area'].isna()) & (data['studio'] == True)] = \
data[(data['kitchen_area'].isna()) & (data['studio'] == True)].fillna(0.)
#Все кухни в студиях помечаем нулем

# %%
data.query('studio == True')[['kitchen_area', 'living_area']].isna().sum()
# Out:
# kitchen_area    0
# living_area     0
# dtype: int64

# %%
data['kitchen_area'].isna().sum()
# Out:
# 2129

# %%
#Пробовал применить такой же метод как и с living_area но кол-ва аномалий выросло в десятки раз, поэтому
data['kitchen_area'] = data['kitchen_area'].fillna(-1) #ставим заглушку здесь для удобной работы в дальнейшем

# %%
data.query('kitchen_area + living_area > total_area') #проверка на изменения в аномалии
# Out:
#           id  total_images  last_price  total_area first_day_exposition  \
# 184      184             7  2600000.00       30.20  2018-02-14T00:00:00
# 545      545             9  4700000.00       23.80  2018-12-28T00:00:00
# 551      551             8  3100000.00       31.59  2018-03-08T00:00:00
# 601      601            12  5600000.00       53.70  2017-04-18T00:00:00
# 696      696             1  3364930.00       34.69  2014-11-27T00:00:00
# ...      ...           ...         ...         ...                  ...
# 21824  21824            20  2450000.00       44.00  2019-02-12T00:00:00
# 21868  21868            12  2600000.00       34.30  2018-09-26T00:00:00
# 21915  21915            14 11990000.00       91.40  2016-05-16T00:00:00
# 21956  21956             0  5200000.00       46.00  2018-07-20T00:00:00
# 23202  23202            13  4919880.00       67.92  2018-10-23T00:00:00
#
#        rooms  ceiling_height  floors_total  living_area  floor is_apartment  \
# ...

# %%
data.isna().sum()
# Out:
# id                          0
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height              0
# floors_total                0
# living_area                 0
# floor                       0
# is_apartment            20790
# studio                      0
# open_plan                   0
# kitchen_area                0
# balcony                     0
# locality_name              49
# airports_nearest         5485
# city_centers_nearest     5462
# parks_around3000         5461
# parks_nearest           15492
# ponds_around3000         5461
# ponds_nearest           14491
# days_exposition          3167
# dtype: int64

# %%
data['is_apartment'].value_counts() #проверяем качественное соотношение заполненных значений
# Out:
# False    2859
# True       50
# Name: is_apartment, dtype: int64

# %% [markdown]
# Колонка `is_apartment` несмотря на то, что пробелов здесь больше всего - мне она кажется одной из простых. Дело в том, что большое число собственников скорее всего даже не задумываются о том, что у них за жилье (и в чем вообще разница). Вполне возможно они просто не поняли смысла этого пункта и пропустили его. В то время как собственники апартаментов скорее больше разбираются в этом вопросе и скорее всего наверняка заполнили эту ячейку. А с учетом того, что большая часть жил. площади скорее всего являются обычными квартирами - осмелюсь предположить, что наличие только 50-ти апартаментов в нашем датасете вполне логично.

# %%
data['is_apartment'] = data['is_apartment'].fillna(False)

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v1:</b>
# <br>👌
# </div>

# %% [markdown]
# Из количественных остается только `days_exposition`. Судя по тому, что большая часть пропусков ложится на более поздние даты начала публикации, то по этим пропускам можно предположить, что данные публикации всё еще активны. Поэтому оставляем всё как есть.

# %%
data[data['days_exposition'].isna() == True].sort_values('first_day_exposition').tail(1500)
# Out:
#           id  total_images  last_price  total_area first_day_exposition  \
# 3284    3284            10  5300000.00       38.90  2019-02-19T00:00:00
# 4696    4696             7  2550000.00       31.90  2019-02-19T00:00:00
# 2232    2232            18  7850000.00       55.70  2019-02-19T00:00:00
# 8754    8754             5 14800000.00       67.30  2019-02-20T00:00:00
# 2876    2876            17  6500000.00       43.80  2019-02-20T00:00:00
# ...      ...           ...         ...         ...                  ...
# 2178    2178            10  5100000.00       51.00  2019-05-03T00:00:00
# 15881  15881             9  2100000.00       35.80  2019-05-03T00:00:00
# 15072  15072             5  1400000.00       34.00  2019-05-03T00:00:00
# 3254    3254            16  8800000.00       80.00  2019-05-03T00:00:00
# 13746  13746            10  7790000.00       42.30  2019-05-03T00:00:00
#
#        rooms  ceiling_height  floors_total  living_area  floor is_apartment  \
# ...

# %% [markdown]
# Скорее всего пропуски `days_exposition` обоснованы активностью объявления.

# %%
data.isna().sum() #проверка проделанной работы (вроде всё сходится)
# Out:
# id                          0
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height              0
# floors_total                0
# living_area                 0
# floor                       0
# is_apartment                0
# studio                      0
# open_plan                   0
# kitchen_area                0
# balcony                     0
# locality_name              49
# airports_nearest         5485
# city_centers_nearest     5462
# parks_around3000         5461
# parks_nearest           15492
# ponds_around3000         5461
# ponds_nearest           14491
# days_exposition          3167
# dtype: int64

# %%
data.groupby('id')['days_exposition'].sum().sort_values()
# Out:
# id
# 0          0.00
# 9842       0.00
# 9837       0.00
# 9819       0.00
# 9816       0.00
#           ...
# 20969   1512.00
# 1885    1513.00
# 9553    1553.00
# 1109    1572.00
# 18843   1580.00
# Name: days_exposition, Length: 23699, dtype: float64

# %% [markdown]
# **Изменение типа данных**

# %% [markdown]
# Рассотрим имеющиеся типы

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 23 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    23699 non-null  int64
#  1   total_images          23699 non-null  int64
#  2   last_price            23699 non-null  float64
#  3   total_area            23699 non-null  float64
#  4   first_day_exposition  23699 non-null  object
#  5   rooms                 23699 non-null  int64
#  6   ceiling_height        23699 non-null  float64
#  7   floors_total          23699 non-null  float64
#  8   living_area           23699 non-null  float64
#  9   floor                 23699 non-null  int64
#  10  is_apartment          23699 non-null  object
#  11  studio                23699 non-null  bool
#  12  open_plan             23699 non-null  bool
#  13  kitchen_area          23699 non-null  float64
#  14  balcony               23699 non-null  float64
# ...

# %% [markdown]
# Первое на что я обратил внимание - это `is_apartment`. При наличи bool-type значений он был записан как object. Вероятнее всего метод заполнения пробелов сам расставил всё на свои места.
#
# Дальше `first_day_exposition` - нужно перевести в формат datetime64 для удобной работы с этими значениями в последствии.
#
# Логично, что `last_price`, `floors_total`, `balcony`, `days_exposition` можно, а может и нужно, перевести в int64. Явной нужды в этом пока нет, но для порядка можно (десятые там не нужны).

# %%
data['days_exposition'] = data['days_exposition'].fillna(1555)
#ставим заглушки на место пропусков в выбранных колонках
data[['floors_total', 'days_exposition']] = data[['floors_total', 'days_exposition']].astype('int64')
#меням тип с float64 на int64

# %% [markdown]
# <div class="alert alert-warning">
# <b>⚠️ Комментарий ревьюера v1:</b>
# <br>Можно изменить тип данных без замены пропусков следующим образом
#
#     import numpy as np
#     df['col'] = np.floor(pd.to_numeric(df['col'], errors='coerce')).astype('Int64')
# </div>

# %%
data.info() #проверка
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 23 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    23699 non-null  int64
#  1   total_images          23699 non-null  int64
#  2   last_price            23699 non-null  float64
#  3   total_area            23699 non-null  float64
#  4   first_day_exposition  23699 non-null  object
#  5   rooms                 23699 non-null  int64
#  6   ceiling_height        23699 non-null  float64
#  7   floors_total          23699 non-null  int64
#  8   living_area           23699 non-null  float64
#  9   floor                 23699 non-null  int64
#  10  is_apartment          23699 non-null  object
#  11  studio                23699 non-null  bool
#  12  open_plan             23699 non-null  bool
#  13  kitchen_area          23699 non-null  float64
#  14  balcony               23699 non-null  float64
# ...

# %%
data['first_day_exposition'] = pd.to_datetime(data['first_day_exposition'], format='%Y-%m-%dT%H:%M:%S')

# %%
data.sample(15)
# Out:
#           id  total_images  last_price  total_area first_day_exposition  \
# 851      851             4  3550000.00       31.60           2016-04-29
# 1522    1522            16  3500000.00       41.50           2018-10-05
# 18202  18202             9  2000000.00       52.80           2018-09-21
# 16777  16777            15  7200000.00       66.70           2017-09-27
# 9397    9397            10 16073000.00      263.80           2019-01-30
# 22226  22226             9  5200000.00       58.70           2018-07-13
# 6602    6602             0  2700000.00       32.90           2017-08-12
# 5933    5933             8  3800000.00       45.80           2018-04-03
# 5277    5277             8  5700000.00       86.00           2017-10-04
# 20432  20432             4  7500000.00       48.00           2018-10-31
# 5687    5687             9  3400000.00       37.50           2015-12-03
# 5750    5750            10  1550000.00       42.30           2017-09-27
# ...

# %% [markdown]
# Теперь разберемся с дубликатами

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Явных дубликатов в датасете нет. Проверим `locality_name` на неявные.

# %%
data['locality_name'].value_counts().head(15)
# Out:
# Санкт-Петербург            15721
# посёлок Мурино               522
# посёлок Шушары               440
# Всеволожск                   398
# Пушкин                       369
# Колпино                      338
# посёлок Парголово            327
# Гатчина                      307
# деревня Кудрово              299
# Выборг                       237
# Петергоф                     201
# Сестрорецк                   183
# Красное Село                 178
# Кудрово                      173
# деревня Новое Девяткино      144
# Name: locality_name, dtype: int64

# %%
data['locality_name'].value_counts().tail(15)
# Out:
# коттеджный поселок Кивеннапа Север    1
# поселок станции Лужайка               1
# посёлок Левашово                      1
# село Шум                              1
# деревня Тойворово                     1
# поселок Володарское                   1
# посёлок Белоостров                    1
# село Никольское                       1
# деревня Лупполово                     1
# деревня Курковицы                     1
# поселок Семиозерье                    1
# деревня Большой Сабск                 1
# деревня Терпилицы                     1
# деревня Куровицы                      1
# поселок Цвылёво                       1
# Name: locality_name, dtype: int64

# %% [markdown]
# Довольно странно видеть столько единичных вариантов. Возможно это и есть наши неявные дубликаты. Можно заметить, что где-то написано "поселок", а где-то "посёлок". Много разных типов поселений мешают найти дубли по самим названиям, поэтому можно пока их убрать

# %%
data['locality_name'].duplicated(False).sum()

#В случае с этим столбцом мы как раз таки хотим как можно больше дубликатов, так как явные здесь исключат неявные
# Out:
# 23595

# %%
data['locality_name'] = data['locality_name'].replace('ё', 'е', regex=True)

# %%
data['locality_name'] = data['locality_name'].replace(
    ['коттеджный ', 'станции ', 'садовое товарищество ', 'при железнодорожной ',
     'село ', 'городской поселок ', 'деревня ', 'поселок ', 'городского типа ', 'садоводческое некоммерческое товарищество '], '', regex=True)
#Оставим поселок через Е. На моём опыте - это более распространенный вариант.

# %%
data['locality_name'].unique()
# Out:
# array(['Санкт-Петербург', 'Шушары', 'Янино-1', 'Парголово', 'Мурино',
#        'Ломоносов', 'Сертолово', 'Петергоф', 'Пушкин', 'Кудрово',
#        'Коммунар', 'Колпино', 'Красный Бор', 'Гатчина', 'Федоровское',
#        'Выборг', 'Кронштадт', 'Кировск', 'Новое Девяткино',
#        'Металлострой', 'Лебяжье', 'Сиверский', 'Молодцово',
#        'Кузьмоловский', 'Новая Ропша', 'Павловск', 'Пикколово',
#        'Всеволожск', 'Волхов', 'Кингисепп', 'Приозерск', 'Сестрорецк',
#        'Куттузи', 'Аннино', 'Ефимовский', 'Плодовое', 'Заклинье',
#        'Торковичи', 'Первомайское', 'Красное Село', 'Понтонный',
#        'Сясьстрой', 'Старая', 'Лесколово', 'Новый Свет', 'Сланцы',
#        'Путилово', 'Ивангород', 'Шлиссельбург', 'Никольское',
#        'Зеленогорск', 'Сосновый Бор', 'Оржицы', 'Кальтино', 'Романовка',
#        'Бугры', 'Рощино', 'Кириши', 'Луга', 'Волосово', 'Отрадное',
#        'Павлово', 'Оредеж', 'Копорье', 'Молодежное', 'Тихвин', 'Победа',
# ...

# %%
data.duplicated(subset='locality_name', keep=False).sum() #Проверим изменения (Успех)
# Out:
# 23620

# %%
23699 - 23620 #получим кол-во уникальных недубликатов
# Out:
# 79

# %%
data['locality_name'].value_counts().tail(80) #проверим всё ли сходится
# Out:
# Путилово           2
# Жилпоселок         1
# Русско             1
# Каськово           1
# Котлы              1
#                   ..
# Цвылево            1
# Малая Романовка    1
# Гончарово          1
# Пчева              1
# Вахнова Кара       1
# Name: locality_name, Length: 80, dtype: int64

# %% [markdown]
# Убрав названия типов поселения - мы скоратили кол-во единичных значений до 79-ти. На мой взгляд в дубликатами покончено, а если что-то закралось - то один-два упущеных значения в общем анализе погоды не сделают.

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v1:</b>
# <br>Супер! Здесь всё верно)
# </div>

# %% [markdown]
# **Поиск аномалий**

# %% [markdown]
# Логично предположить, что перед тем как удалять аномалии, нужно определить нормы. Посмотрим, что мы сможем увидеть через describe() и boxplot.

# %%
data.describe()
# Out:
#             id  total_images   last_price  total_area    rooms  \
# count 23699.00      23699.00     23699.00    23699.00 23699.00
# mean  11849.00          9.86   6541548.77       60.35     2.07
# std    6841.46          5.68  10887013.27       35.65     1.08
# min       0.00          0.00     12190.00       12.00     0.00
# 25%    5924.50          6.00   3400000.00       40.00     1.00
# 50%   11849.00          9.00   4650000.00       52.00     2.00
# 75%   17773.50         14.00   6800000.00       69.90     3.00
# max   23698.00         50.00 763000000.00      900.00    19.00
#
#        ceiling_height  floors_total  living_area    floor  kitchen_area  \
# count        23699.00      23699.00     23699.00 23699.00      23699.00
# mean             2.72         10.67        34.61     5.89          9.46
# std              0.99          6.60        22.37     4.89          6.56
# min              1.00          1.00         2.00     1.00         -1.00
# ...

# %% [markdown]
# Думаю, ориентироваться будем по основным показателям, таким как `last_price`, `total_area`, `ceiling_height`, `rooms`, `days_exposition`
#
# Тут сразу видны сильно завышенные максимальные и сильно заниженные минимальные показатели.

# %%
data[['last_price', 'total_area', 'ceiling_height', 'rooms', 'days_exposition']].describe()
# Out:
#         last_price  total_area  ceiling_height    rooms  days_exposition
# count     23699.00    23699.00        23699.00 23699.00         23699.00
# mean    6541548.77       60.35            2.72     2.07           364.41
# std    10887013.27       35.65            0.99     1.08           510.37
# min       12190.00       12.00            1.00     0.00             0.00
# 25%     3400000.00       40.00            2.60     1.00            45.00
# 50%     4650000.00       52.00            2.65     2.00           124.00
# 75%     6800000.00       69.90            2.70     3.00           389.00
# max   763000000.00      900.00          100.00    19.00          1580.00

# %%
data.boxplot(column='ceiling_height', return_type='axes', figsize=(15,10)) 
plt.show()

# %% [markdown]
# Начнем с ceiling height, тут будет довольно просто отсеять аномалии. Много сильно завышеных показателей, но возможно кто-то забыл поставить запятую в нужном месте. Поэтому сначала попытаемся это исправить.

# %%
for _ in data['ceiling_height']:
    if _ >= 9:
        data['ceiling_height'] = data['ceiling_height'].replace(_, _/10)

# %%
data[data['total_images'] == data['total_images'].max()]
# Out:
#           id  total_images  last_price  total_area first_day_exposition  \
# 9778    9778            50 11000000.00       87.00           2017-10-25
# 12667  12667            50 20500000.00       76.00           2017-12-10
# 17396  17396            50 14500000.00      119.70           2017-12-02
#
#        rooms  ceiling_height  floors_total  living_area  floor is_apartment  \
# 9778       2            2.65            25        32.50     11        False
# 12667      3            2.65            20        47.00     16        False
# 17396      4            4.00             4        87.50      3        False
#
#        studio  open_plan  kitchen_area  balcony    locality_name  \
# 9778    False      False         31.00     5.00  Санкт-Петербург
# 12667   False      False         29.00     0.00  Санкт-Петербург
# 17396   False      False         13.50     0.00  Санкт-Петербург
#
#        airports_nearest  city_centers_nearest  parks_around3000  \
# ...

# %%
data.boxplot(column='ceiling_height', return_type='axes', figsize=(15,10)) 
plt.show()

# %% [markdown]
# После предварительной обработки диаграмма лишь немного встала на место, в конечном итоге скорее всего придется отсеять все показатели до 2,2 и после 5 метров.

# %%
data['ceiling_height'][data['ceiling_height'] <= 5].hist(bins=100, range=(2,5), figsize=(10,5))
# Out:
# <AxesSubplot:>

# %% [markdown]
# Диаграмму довольно сложно читать. Поэтому сначала можно перевести цену в миллионы. А чуть позже убрать слишком выдающиеся значения. Например, можно будет отфильтровать все ценники выше 200млн.

# %%
data['last_price'] = data['last_price']/1000000

# %%
data.boxplot(column='last_price', return_type='axes', figsize=(15,10)) 
plt.show()

# %%
data['last_price'][data['last_price'] <= 50].hist(bins=100, figsize=(15,10))
plt.show()

# %%
data.boxplot(column='total_area', return_type='axes', figsize=(15,10)) 
plt.show()

# %% [markdown]
# Видим явныe выбросы, но можно посмотреть и поближе. Думаю, что после 250 м2 остаются только весьма редкие значения и их можно считать аномалиями.

# %%
data['total_area'].hist(bins=150, range=(0,260), figsize=(15,9))
plt.show()

# %%
data.boxplot(column='rooms', return_type='axes', figsize=(15,10)) 
plt.show()

# %%
data['rooms'].hist(bins=100, figsize=(15,9))
plt.show()

# %%
data[data['rooms'] == data['rooms'].max()]
# Out:
#           id  total_images  last_price  total_area first_day_exposition  \
# 14498  14498             6       32.25      374.60           2018-06-09
#
#        rooms  ceiling_height  floors_total  living_area  floor is_apartment  \
# 14498     19            2.65             5       264.50      2        False
#
#        studio  open_plan  kitchen_area  balcony    locality_name  \
# 14498   False      False         27.60     0.00  Санкт-Петербург
#
#        airports_nearest  city_centers_nearest  parks_around3000  \
# 14498          19497.00               3574.00              0.00
#
#        parks_nearest  ponds_around3000  ponds_nearest  days_exposition
# 14498            NaN              2.00         548.00              114

# %% [markdown]
# Здесь, всё что после 7 - почти не заметно на графике, и выбросов довольно немного. Аномалий не вижу, кроме помещения с 19-ю комнатами, но эта строка должна уйти по другим параметрам.

# %%
data.boxplot(column='days_exposition', return_type='axes', figsize=(15,10)) 
plt.show()

# %%
data['days_exposition'][data['days_exposition'] <= 1400].hist(bins=200,range=(0,1400), figsize=(15,10))
plt.show()

# %% [markdown]
# В данном случае все пропуски выставлены за пределы гистограммы. На самом графике мы видим много выбросов, но аномальных значений пока не вижу. Вполне логично, что объявление может активным и 3 года, и 5 лет. Оно может быть уже неактуальным, но ошибки в заполнении/выгрузки данных тут нет.

# %%
data[data['days_exposition'] == data['days_exposition'].max()]
# Out:
#           id  total_images  last_price  total_area first_day_exposition  \
# 18843  18843            11        3.50       48.20           2014-12-15
#
#        rooms  ceiling_height  floors_total  living_area  floor is_apartment  \
# 18843      2            2.50             5        27.40      2        False
#
#        studio  open_plan  kitchen_area  balcony    locality_name  \
# 18843   False      False          7.70     3.00  Новое Девяткино
#
#        airports_nearest  city_centers_nearest  parks_around3000  \
# 18843               NaN                   NaN               NaN
#
#        parks_nearest  ponds_around3000  ponds_nearest  days_exposition
# 18843            NaN               NaN            NaN             1580

# %%
data.query('kitchen_area + living_area > total_area')

#Ранее мы выяснили, что существует и такая аномалия. Думаю их тоже можно убрать.
# Out:
#           id  total_images  last_price  total_area first_day_exposition  \
# 184      184             7        2.60       30.20           2018-02-14
# 545      545             9        4.70       23.80           2018-12-28
# 551      551             8        3.10       31.59           2018-03-08
# 601      601            12        5.60       53.70           2017-04-18
# 696      696             1        3.36       34.69           2014-11-27
# ...      ...           ...         ...         ...                  ...
# 21824  21824            20        2.45       44.00           2019-02-12
# 21868  21868            12        2.60       34.30           2018-09-26
# 21915  21915            14       11.99       91.40           2016-05-16
# 21956  21956             0        5.20       46.00           2018-07-20
# 23202  23202            13        4.92       67.92           2018-10-23
#
#        rooms  ceiling_height  floors_total  living_area  floor is_apartment  \
# ...

# %%
data_new = data.query('last_price < 200 and total_area <= 250 and ceiling_height < 5 and ceiling_height > 2.2 and kitchen_area + living_area < total_area')
# and kitchen_area + living_area < total_area

# %%
data['id'].count()
# Out:
# 23699

# %%
data_new['id'].count()
# Out:
# 23413

# %%
data_new.describe()
# Out:
#             id  total_images  last_price  total_area    rooms  ceiling_height  \
# count 23413.00      23413.00    23413.00    23413.00 23413.00        23413.00
# mean  11851.41          9.84        6.16       59.01     2.05            2.69
# std    6841.41          5.67        6.43       28.89     1.03            0.21
# min       0.00          0.00        0.01       12.00     0.00            2.25
# 25%    5928.00          6.00        3.40       40.00     1.00            2.60
# 50%   11852.00          9.00        4.60       52.00     2.00            2.65
# 75%   17778.00         14.00        6.70       69.19     3.00            2.70
# max   23698.00         50.00      160.00      250.00    14.00            4.90
#
#        floors_total  living_area    floor  kitchen_area  balcony  \
# count      23413.00     23413.00 23413.00      23413.00 23413.00
# mean          10.69        33.78     5.89          9.34     0.59
# std            6.59        18.81     4.89          6.22     0.96
# ...

# %%
data_new.hist(bins=100, figsize=(15,20))
plt.show()

# %% [markdown]
# <div class="alert alert-info"> Было желание убрать полностью все выбросы, но я был неуверен насколько это может исказить картину</div>

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v1:</b>
# <br>Диапазоны для аномальных значений подобраны и удалены верно! Можно смело удалять до 10% данных
# </div>

# %% [markdown]
# ### Посчитайте и добавьте в таблицу новые столбцы

# %%
#Довольно поздно решил переименовать столбец, поэтому делаю сейчас, чтобы миллионы обратно не переводить в рубли
data_new = data_new.rename(columns={'last_price': 'last_price_mil'})
data_new['price_of_m2_rub'] = (data_new['last_price_mil']/data_new['total_area'])*1000000 #пусть у нас новый стоблец будет в рублях, чтобы голову не ломать
data_new['price_of_m2_rub'] = data_new['price_of_m2_rub'].round(decimals=0) #округляем и сразу преобразоываем в int64
data_new['price_of_m2_rub'] = data_new['price_of_m2_rub'].astype('int64')

# %%
#Добавим по отдельность день недели, месяц и год в нашу таблицу
data_new['day'] = data_new['first_day_exposition'].dt.weekday
data_new['month'] = data_new['first_day_exposition'].dt.month_name()
data_new['year'] = data_new['first_day_exposition'].dt.year

# %%
# Уберем метры из столбцов с прудами, аэропортами и центрами городам, приведем все к километрам
data_new['city_centers_nearest_km'] = data_new['city_centers_nearest'] / 1000
data_new['city_centers_nearest_km'] = data_new['city_centers_nearest_km'].round(decimals=0)

# %%
# Добавим этажи
def floor_count(row):
    if row['floor'] == 1:
        return 'первый'
    elif row['floor'] == row['floors_total']:
        return 'последний'
    else:
        return 'другой'

# %%
data_new['floor_type'] = data_new.apply(floor_count, axis=1)

# %%
data_new.sample(15) #Вроде всё на месте
# Out:
#           id  total_images  last_price_mil  total_area first_day_exposition  \
# 21865  21865             1            7.60       66.60           2018-02-06
# 18388  18388            11            3.65       66.50           2019-03-15
# 18194  18194             6            2.29       55.00           2018-08-28
# 2309    2309            10            4.20       62.40           2017-06-15
# 4676    4676            18            3.70       48.10           2018-12-18
# 21115  21115             9            3.90       34.25           2018-09-25
# 4781    4781            10            6.80       62.40           2019-04-19
# 15657  15657            12            6.90       71.60           2019-05-01
# 20076  20076             3            4.00       39.00           2019-03-13
# 17554  17554             9            3.10       33.00           2017-09-12
# 8260    8260             5            3.75       45.69           2016-08-07
# ...

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v1:</b>
# <br>Все необходимые колонки добавлены. Идём дальше)
# </div>

# %% [markdown]
# ### Проведите исследовательский анализ данных

# %% [markdown]
# ### Изучим следующие параметры объектов:
#
#   - общая площадь;
#   - жилая площадь;
#   - площадь кухни;
#   - цена объекта;
#   - количество комнат;
#   - высота потолков;
#   - этаж квартиры;
#   - тип этажа квартиры («первый», «последний», «другой»);
#   - общее количество этажей в доме;
#   - расстояние до центра города в метрах;
#   - расстояние до ближайшего аэропорта;
#   - расстояние до ближайшего парка;
#   - день и месяц публикации объявления

# %%
data_new.boxplot(column='total_area', return_type='axes', showfliers=False, figsize=(15,9))
plt.show()
data_new['total_area'].plot(kind='hist', figsize=(15,9), grid=True, bins=100, range=(20,150))
plt.show()

# %% [markdown]
# Здесь мы видим более-менее равномерное распределение квартир в основном от 40 до 70 м2, квартиры после 80м2 встречаются всё реже, а больше 120 м2 и вовсе не сыщешь. Пики данных на нашей гистограмме скорее всего определены разными типами застроек, которых на самом деле не так уж и много, так как планировка должна пройти много уровней проверок, перед тем как попасть в производство.

# %%
data_new.boxplot(column='living_area', return_type='axes', showfliers=False, figsize=(15,9))
plt.show()
data_new['living_area'].plot(kind='hist', figsize=(15,9), grid=True, bins=110, range=(10,80))
plt.show()

# %% [markdown]
# Здесь мы видим логичную картину, которая почти напрямую коррелирует с общей площадью. За исключением иного распределения пиков значений. Я предположу, что здесь еще идет ориентировка на количество комнат, где комнаты занимают пропорциональное друг другу пространство. В итоге мы видим что, скорее всего, первый пик - это однокомнатные квартиры, а второй - двухкомнатные.

# %%
data_new.boxplot(column='kitchen_area', return_type='axes', showfliers=False, figsize=(15,9))
plt.show()
data_new['kitchen_area'].plot(kind='hist', figsize=(15,9), grid=True, bins=100, range=(0,30))
plt.show()

# %% [markdown]
# Тут мы видим, что в основном кухня занимает где-то 6-14 м2. Нулевые значения обозначают квартиры-студии. Кухни больше 15м2 встречаются реже, после 30м2 - уже большая редкость.

# %%
data_new.boxplot(column='last_price_mil', return_type='axes', showfliers=False, figsize=(15,9))
plt.show()
data_new['last_price_mil'].plot(kind='hist', figsize=(15,9), range=(0,20), grid=True, bins=80)
plt.show()
data_new['last_price_mil'].describe()
# Out:
# count   23413.00
# mean        6.16
# std         6.43
# min         0.01
# 25%         3.40
# 50%         4.60
# 75%         6.70
# max       160.00
# Name: last_price_mil, dtype: float64

# %% [markdown]
# Здесь мы видим, что большая часть квартир идет в продажу от 10-12 тыс. до 10 млн.руб со средней ценой в 6млн., с квартирами за 20млн уже будучи большой редкостью. Самые дешевые варианты можно объяснить очень плохим состоянием квартиры, или продажу комнат в коммуналке.

# %%
data_new.boxplot(column='ceiling_height', return_type='axes', showfliers=False, figsize=(15,9))
plt.show()
data_new['ceiling_height'].plot(kind='hist', figsize=(15,9), grid=True, range=(2.25,4), bins=70)
plt.show()

# %% [markdown]
# Здесь всё довольно оправдано средними числами, гост есть гост - всё находится в пределах плюс-минус 2.6 метров, с адекватным максимумом до 3х метров, и большой редкостью после.

# %%
data_new.boxplot(column='floor', return_type='axes', showfliers=False, figsize=(15,9))
plt.show()
data_new['floor'].plot(kind='hist', figsize=(15,9), grid=True, bins=70)
plt.show()

# %% [markdown]
# Тут тоже всё просто, большая часть квартир находтся в пределах 5-ти этажей, после 10-ти идущих на сильный спад. Из чего можно предположить, что большая часть домов находится именно в пределах максимум 10-ти этажей, что было бы довольно характерно для СпБ и области.

# %%
data_new.boxplot(column='floors_total', return_type='axes', showfliers=False, figsize=(15,9))
plt.show()
data_new['floors_total'].plot(kind='hist', figsize=(15,9), grid=True, bins=30, range=(0,30))
plt.show()

# %% [markdown]
# Что мы так же можем видеть на этой гистограмме. Дома выше 10-ти этажных находятся в более-менее равной доле, но в подавляющем меньшинстве. Предположу, что пики - это основные жилые архетектурные проекты, а всё остальное - либо загородные дома, либо исторические здания.

# %%
data_new['floor_type'].value_counts().plot(kind='pie', figsize=(7,7))
plt.show()

# %% [markdown]
# Тут работает банальная статистика, вполне ожидаемое распределение значений. Первому и последнему этажу нечего противопоставить коллективной мощи других этажей.

# %%
data_new.boxplot(column='city_centers_nearest', return_type='axes', showfliers=False, figsize=(15,9))
plt.show()
data_new['city_centers_nearest'].plot(kind='hist', figsize=(15,9), grid=True, bins=100)
plt.show()

# %% [markdown]
# По данным, которые у нас есть, мы можем видеть, что подавляющее кол-во жилой недвижимости находится или в самом центе или до 20км, часть находится от 20 до 40 км, совсем редкость 50км.

# %%
data_new.boxplot(column='airports_nearest', return_type='axes', showfliers=False, figsize=(15,9))
plt.show()
data_new['airports_nearest'].plot(kind='hist', figsize=(15,9), grid=True, bins=200)
plt.show()

# %% [markdown]
# Здесь мы можем видеть, что большинство продаваемой недвижимости находится в 20-40км от аэропорта. В достаточной близости, примерно в часе пути на машине. Чуть реже - от 40 до 60км, совсем редко дл 80км. Из этого можно предположить, что большая часть недвижимости находится или в самом Питере или близко, так как расстояние от центра города до аэропорта обычно довольно стабилное.

# %%
data_new.boxplot(column='parks_nearest', return_type='axes', showfliers=False, figsize=(15,9))
plt.show()
data_new['parks_nearest'].plot(kind='hist', figsize=(15,9), grid=True, bins=100)
plt.show()

# %% [markdown]
# Из того небольшого среза данных, что у нас есть, можно предположить, что подавляющее большинство жил.площади находится в пределах от совершенной близости до километра. В среднем расстояние составляет около 500м. Здесь предположу, что пропуски в данных могут быть обусловлены большой дальностью от парков. А раз парки в рекламу не входят, то и указывать незачем.

# %%
data_new['month'].value_counts().plot(kind='bar', figsize=(15,9))
plt.show()
data_new['day'].value_counts().plot(kind='bar', figsize=(15,9))
plt.show()

# %% [markdown]
# Тут дата нам показывает, что люди занимаются продажей своих квартир в начале весны Февраль-Апрель и осенью Сентябрь-Ноябрь, в остальные промежутки активность гораздно меньше. Предположим что в летний период люди уезжают отдыхать, а в зимний период - там и так забот хватает: Новый Год, да и тот же отпуск.
#
# Что касается среза по дням недели, тут видно что люди предпочитают занимать продажей недвижимости в будние дни. В выходные - гораздо реже.

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v1:</b>
# <br>Ты корректно подбираешь основные диапазоны, а также верно читаешь графики!
# </div>
#
# <div class="alert alert-warning">
# <b>⚠️ Комментарий ревьюера v1:</b>
# <br>Для того чтобы подписать график мы можем использовать метод plt.title() и в конце кода применить plt.show(). По ссылкам ниже можно почитать подробнее как добавить название для графика или подписать его оси
#
#     https://pyprog.pro/mpl/mpl_title.html
#     https://pyprog.pro/mpl/mpl_axis_signatures.html
# </div>

# %% [markdown]
# ### Изучаем, как быстро продавались квартиры (столбец days_exposition). Этот параметр показывает, сколько дней было размещено каждое объявление.

# %%
data_new['days_exposition'].describe()
# Out:
# count   23413.00
# mean      363.49
# std       509.64
# min         0.00
# 25%        45.00
# 50%       124.00
# 75%       388.00
# max      1580.00
# Name: days_exposition, dtype: float64

# %%
data_new.query('days_exposition != 1555').pivot_table(index='year', values='days_exposition', aggfunc=['mean', 'median']).plot(figsize=(15,10))
plt.show()

# %%
data_new.pivot_table(index='year', values='days_exposition', aggfunc=['mean', 'median']).plot(figsize=(15,10))
plt.show()

#Здесь я убрал заглушки, чтобы показать наглядно, что большая часть активных объявлений приходится на 2019 год

# %%
data_new['year'].value_counts().plot(kind='pie', figsize=(10,10))
plt.show()

# %% [markdown]
# Разберемся сначала с продаваемостью квартир относительно годов. Судя по графику наблюдается довольно стабильная прогрессия скорости продажи с 2014 года по 2019. Долгие продажи могут быть связаны с качеством квартир, и с огромным количеством факторов связанных с качеством собственников.
#
# **Но мне кажется, что судя по этим графикам, я предположу, что это напрямую связано с качеством сервиса. Предположу, что в 2014 году сервис (каким мы его знаем сегодня) только зародился и не имел устойчивой платформы для продвижения и продажи объявлений. Тут мы видим постепенный рост клиентуры с 14 по 17 года, незначительный рост (если он вообще был) в 2018 году, и, вероятно снижение сатурации рынка в 2019 году (но возможно мы имеем не полные данные на весь 2019 год). На графике 2019 год включает в себя активные объявления, на деле кол-во законченных сделок на 2019 год гораздо меньше. Я всё-таки предположу, что срез данных был снят на начало 2019 года.**

# %%
data_new.query('days_exposition != 1555')['days_exposition'].hist(bins=100, grid=True, figsize=(15,10), range=(0,1200))
#plt.xticks(np.arange(5,1200,10))
plt.show()

# %% [markdown]
# Здесь мы видим, что большая часть продаж совершилось в период до 200 дней, а если мы рассмотрим поближе, то увидим, что нынче квартиры продают еще быстрее - в течени 2х месяцев. Долгими можно счесть продажи от года и дальше.

# %%
data_new.query('days_exposition != 1555')['days_exposition'].hist(bins=100, grid=True, range=(0,200), figsize=(15,10))
plt.xticks(np.arange(5,200,10))
plt.show()

# %% [markdown]
# Посмотрим детальнее на основную часть распределения у видим пики в пределах 45-ти и 60-ти дней. Видимо, это сваязано с особенностями сервиса Я-Недвижимость. Я посмотрел их условия, там установлена доп оплата за каждые 30 дней платного объяления. Здесь 60 дневные периоды имеют смысл, но это может совершенно не означать продажи. Люди могли снимать свои объявления, чтобы у них не снимали деньги. Насчёт 45-ти дней не уверен - возможно в какой-то момент автоплатежный период составлял 15 дней, а не 30.

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v1:</b>
# <br>Здорово, что ты заметил эти всплески! Это действительно особенность функционирования системы размещения объявлений. Убедиться в этом можно по ссылке ниже
#
# 	https://yandex.ru/support/realty/owner/home/add-ads-housing.html
# </div>

# %% [markdown]
# ### Какие факторы больше всего влияют на общую (полную) стоимость объекта? Изучим, зависит ли цена от:
#
# - общей площади;
# - жилой площади;
# - площади кухни;
# - количества комнат;
# - этажа, на котором расположена квартира (первый, последний, другой);
# - даты размещения (день недели, месяц, год).

# %%
data_new.head()
# Out:
#    id  total_images  last_price_mil  total_area first_day_exposition  rooms  \
# 0   0            20           13.00      108.00           2019-03-07      3
# 1   1             7            3.35       40.40           2018-12-04      1
# 2   2            10            5.20       56.00           2015-08-20      2
# 3   3             0           64.90      159.00           2015-07-24      3
# 4   4             2           10.00      100.00           2018-06-19      2
#
#    ceiling_height  floors_total  living_area  floor is_apartment  studio  \
# 0            2.70            16        51.00      8        False   False
# 1            2.65            11        18.60      1        False   False
# 2            2.65             5        34.30      4        False   False
# 3            2.65            14        91.18      9        False   False
# 4            3.03            14        32.00     13        False   False
#
# ...

# %%
data_new.query('kitchen_area != -1')[['last_price_mil', 'total_area', 'living_area', 'kitchen_area', 'rooms']].corr()
# Out:
#                 last_price_mil  total_area  living_area  kitchen_area  rooms
# last_price_mil            1.00        0.72         0.62          0.56   0.43
# total_area                0.72        1.00         0.93          0.59   0.79
# living_area               0.62        0.93         1.00          0.37   0.87
# kitchen_area              0.56        0.59         0.37          1.00   0.24
# rooms                     0.43        0.79         0.87          0.24   1.00

# %% [markdown]
# На общую стоимость квартиры сильнее всего влияют её общая площадь и жилая площадь. В меньшей степени, но всё еще достаточно важна - это площадь кухни, а в самую последнюю очередь - количество комнат.

# %%
data_new.boxplot('last_price_mil', by='day',figsize=(10,10), showfliers=False)
plt.show()

# %% [markdown]
# Судя по графику день объявления квартиры на продажу не имеет никакого влияния на цену.

# %%
data_new.boxplot('last_price_mil', by='month',figsize=(10,10), showfliers=False)
plt.show()

# %% [markdown]
# Здесь тоже корреляции не заметно. Где-то побольше, где-то поменьше, но ничего серьезного.

# %%
data_new.boxplot('last_price_mil', by='year',figsize=(10,10), showfliers=False)
plt.show()

# %% [markdown]
# Вот здесь уже интереснее, в 2014 году наблюдался наивысший пик цен, после чего довольно резко всё уравнялось. Причина скорее всего была в развитии платформы, резко нараставшего кол-ва объявлений и соответсвенно - конкуренции.

# %%
data_new.boxplot('last_price_mil', by='floor_type',figsize=(10,10), showfliers=False)
plt.show()

# %% [markdown]
# Здесь выделяется только первый этаж. Квартиры тут определенно дешевле.

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v1:</b>
# <br>Зависимость цены изучена верно! Ещё тут можно использовать для визуализации pairplot из библиотеки seaborn
#
#     https://seaborn.pydata.org/generated/seaborn.pairplot.html
# </div>

# %% [markdown]
# ### Посчитаем среднюю цену одного квадратного метра в 10 населённых пунктах с наибольшим числом объявлений. Выделим населённые пункты с самой высокой и низкой стоимостью квадратного метра.

# %%
data_new['locality_name'].value_counts()
# Out:
# Санкт-Петербург    15512
# Мурино               584
# Кудрово              468
# Шушары               438
# Всеволожск           391
#                    ...
# Цвылево                1
# Малая Романовка        1
# Гончарово              1
# Пчева                  1
# Вахнова Кара           1
# Name: locality_name, Length: 305, dtype: int64

# %%
#создаем новый датафрейм с помощью pivot_table, и сразу рассчитываем нужные нам значения.
pm2_data = data_new.pivot_table(index='locality_name', values='price_of_m2_rub', aggfunc=['count', 'mean', 'median']).droplevel(1, axis=1)
#Избавляемся от мультииндекса и сортируем таблицу, выводя нужные нам 10 строк
pm2_data = pm2_data.sort_values('count', ascending=False).reset_index()
pm2_data = pm2_data.loc[0:9]
pm2_data
# Out:
#      locality_name  count      mean    median
# 0  Санкт-Петербург  15512 113655.48 104630.00
# 1           Мурино    584  85957.07  86093.50
# 2          Кудрово    468  95247.68  95555.00
# 3           Шушары    438  78610.92  76748.00
# 4       Всеволожск    391  68617.80  65789.00
# 5           Пушкин    366 103185.75 100000.00
# 6          Колпино    336  75389.15  74723.50
# 7        Парголово    326  90135.05  91580.00
# 8          Гатчина    303  68625.11  67647.00
# 9           Выборг    232  58402.60  58417.00

# %%
pm2_data.sort_values('mean', ascending=False)
# Out:
#      locality_name  count      mean    median
# 0  Санкт-Петербург  15512 113655.48 104630.00
# 5           Пушкин    366 103185.75 100000.00
# 2          Кудрово    468  95247.68  95555.00
# 7        Парголово    326  90135.05  91580.00
# 1           Мурино    584  85957.07  86093.50
# 3           Шушары    438  78610.92  76748.00
# 6          Колпино    336  75389.15  74723.50
# 8          Гатчина    303  68625.11  67647.00
# 4       Всеволожск    391  68617.80  65789.00
# 9           Выборг    232  58402.60  58417.00

# %% [markdown]
# Данные нам говорят о том, что самое дорогое жильё - в Питере, а самое дешёвое - в Выборге. Логично.

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v1:</b>
# <br>Всё верно! Как вариант, тут можно построить барплот для топ10, так будет более наглядно)
# </div>

# %% [markdown]
# ### Теперь выделим квартиры в Санкт-Петербурге с помощью столбца locality_name и вычислим среднюю цену каждого километра. Опишем, как стоимость объектов зависит от расстояния до центра города.

# %%
data_new.sample()
# Out:
#           id  total_images  last_price_mil  total_area first_day_exposition  \
# 17993  17993             8            2.65       32.00           2018-09-17
#
#        rooms  ceiling_height  floors_total  living_area  floor is_apartment  \
# 17993      1            2.50             4        17.00      3        False
#
#        studio  open_plan  kitchen_area  balcony locality_name  \
# 17993   False      False         -1.00     0.00     Ломоносов
#
#        airports_nearest  city_centers_nearest  parks_around3000  \
# 17993          49433.00              52858.00              2.00
#
#        parks_nearest  ponds_around3000  ponds_nearest  days_exposition  \
# 17993         501.00              3.00         505.00               71
#
#        price_of_m2_rub  day      month  year  city_centers_nearest_km  \
# 17993            82812    0  September  2018                    53.00
#
#       floor_type
# 17993     другой

# %%
data_new['city_centers_nearest_km'] = data_new['city_centers_nearest_km'].fillna(-1) #заглушки на всякий случай

# %%
#делаем то же самое, что и в прошлом задании, только непосредственно для СпБ
spb_data = data_new.query('locality_name == "Санкт-Петербург" and city_centers_nearest_km != -1') \
.pivot_table(index='city_centers_nearest_km', values='price_of_m2_rub', aggfunc=['median','mean'])

# %%
spb_data.plot(figsize=(15,10))
plt.show()

# %%
data_new.query('locality_name == "Санкт-Петербург" and city_centers_nearest_km == 3')
# Out:
#           id  total_images  last_price_mil  total_area first_day_exposition  \
# 99        99            32            9.60       90.00           2017-09-26
# 138      138             8            4.80       40.00           2017-11-18
# 154      154             1            8.20       80.00           2018-11-06
# 179      179             5           14.80      108.70           2019-04-11
# 181      181             2            7.90       71.80           2017-08-23
# ...      ...           ...             ...         ...                  ...
# 23178  23178             7            5.95       60.00           2018-02-01
# 23387  23387             7            5.60       50.00           2017-08-21
# 23430  23430            18            5.26       38.00           2018-11-06
# 23449  23449             4            6.30       52.60           2015-05-28
# 23555  23555             5           15.35      158.50           2019-03-07
#
# ...

# %%
data_new.query('locality_name == "Санкт-Петербург" and city_centers_nearest_km == 27')
# Out:
#         id  total_images  last_price_mil  total_area first_day_exposition  \
# 748    748            13           14.35       74.00           2017-11-28
# 5961  5961             6            2.25       32.00           2018-02-27
#
#       rooms  ceiling_height  floors_total  living_area  floor is_apartment  \
# 748       2            3.13             5        30.00      3        False
# 5961      1            2.65             2        16.50      2        False
#
#       studio  open_plan  kitchen_area  balcony    locality_name  \
# 748    False      False         25.00     0.00  Санкт-Петербург
# 5961   False      False          7.00     0.00  Санкт-Петербург
#
#       airports_nearest  city_centers_nearest  parks_around3000  parks_nearest  \
# 748           23888.00              27313.00              1.00        1496.00
# 5961          24006.00              27431.00              0.00            NaN
#
#       ponds_around3000  ponds_nearest  days_exposition  price_of_m2_rub  day  \
# ...

# %%
spb_data.plot(kind='bar', figsize=(15,10))
plt.show()

# %% [markdown]
# Зависимость цены недвижимости от расстояния от центра - практически прямая, за исключением пары моментов, где цена слишком занижена или слишком завышена. В отношении низкой цены ближе к центру - я бы сказал, что вплоне возможно квартиры находятся в неблагоприятном районе, с обветшалыми домами (мы же с вами всё-таки про Петербург говорим).
#
# А если смотреть на пик на 27 километре - то можно предположить обратное. Новая застройка, коттеджный посёлок, в близости ко всем крупным магазинам, да и до аэропорта минут 20 наверное.

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v1:</b>
# <br>Верно 👍
# </div>

# %% [markdown]
# ### Общий вывод

# %% [markdown]
# Сделаем выводы и на основе данных о корреляции, и на основе графиков.
#
#
# Самые популярные квартиры на маркетплейсе - это вполне стандартные 40м2 общей площади (3:2 жил.площади), с потолками 2.6 метра, скорее всего в 5-ти или 10-ти этажном здании, в относительной близости к центру(или к городу).
#
# Факторы, которые сильнее всего влияют на конечную цену:
#
# - `Метраж/Доля жилой площади` Общая цена напрямую зависит от метража и доли жилой площади
# - `Доля кухни/Количество комнат` Доля кухонной площади и кол-во комнат так же поднимают цену, но в слегка меншей степени
# - `Удаленность от центра` Чем ближе к центру, тем дороже квартира. В самом центре (< 1 км до центра) квартиры стоят на порядок дороже, чем на более удаленных.
# - `Этаж` На первом этаже квартиры немного дешевле остальных, но влияние на общую цену - минимальное.
#
# Остальные факторы:
#
# - `День размещения объявления Квартиры` - цены от дня недели не зависят
# - `Месяц размещения объявления Квартиры`-  цены практически не зависят от времени года, но активность продавцов наблюдается в начало весны и к концу осени.
# - `Год размещения объявления Квартиры` - размещенные к продаже в 2014 году, дороже всех. Период 2015-2019 цены стабилизировались, платформа набирает обороты..

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьюера v1:</b>
# <br>Здесь всё верно 👍
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Итоговый комментарий ревьюера v1:</b>
# <br>Я бы мог принять твою работу с первого раза, но хочу дать тебе возможность задать мне вопросы) Если вопросов нет, то я с радостью приму проект)
# </div>

# %% [markdown]
# <div class="alert alert-info"> Спасибо, за ревью! Вопросов пока нет, спасибо за заметки. Отпр </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Итоговый комментарий ревьюера v2:</b>
# <br>Я рад был поработать над проверкой твоей работы) В качестве дополнительного материала для изучения могу порекомендовать следующий ресурс:
#
# 	https://www.python-graph-gallery.com/
# <br>В нем содержится большая библиотека графиков с готовым кодом, который можно использовать при работе.
# <br>Поздравляю со сдачей проекта и желаю удачи в дальнейшем обучении! 😉
# </div>

# %% [markdown]
# **Чек-лист готовности проекта**
#
# Поставьте 'x' в выполненных пунктах. Далее нажмите Shift+Enter.

# %% [markdown]
# - [x]  открыт файл
# - [x]  файлы изучены (выведены первые строки, метод `info()`, гистограммы и т.д.)
# - [x]  определены пропущенные значения
# - [x]  заполнены пропущенные значения там, где это возможно
# - [x]  есть пояснение, какие пропущенные значения обнаружены
# - [x]  изменены типы данных
# - [x]  есть пояснение, в каких столбцах изменены типы и почему
# - [x]  устранены неявные дубликаты в названиях населённых пунктов
# - [x]  устранены редкие и выбивающиеся значения (аномалии) во всех столбцах
# -----------------
# - [x]  посчитано и добавлено в таблицу: цена одного квадратного метра
# - [x]  посчитано и добавлено в таблицу: день публикации объявления (0 - понедельник, 1 - вторник и т.д.)
# - [x]  посчитано и добавлено в таблицу: месяц публикации объявления
# - [x]  посчитано и добавлено в таблицу: год публикации объявления
# - [x]  посчитано и добавлено в таблицу: тип этажа квартиры (значения — «первый», «последний», «другой»)
# - [x]  посчитано и добавлено в таблицу: расстояние в км до центра города
# --------------------------------
# - [x]  изучены и описаны следующие параметры:
#         - общая площадь;
#         - жилая площадь;
#         - площадь кухни;
#         - цена объекта;
#         - количество комнат;
#         - высота потолков;
#         - этаж квартиры;
#         - тип этажа квартиры («первый», «последний», «другой»);
#         - общее количество этажей в доме;
#         - расстояние до центра города в метрах;
#         - расстояние до ближайшего аэропорта;
#         - расстояние до ближайшего парка;
#         - день и месяц публикации объявления
#
#
# - [x]  построены гистограммы для каждого параметра
# - [x]  выполнено задание: "Изучите, как быстро продавались квартиры (столбец days_exposition). Этот параметр показывает, сколько дней «висело» каждое объявление.
#     - Постройте гистограмму.
#     - Посчитайте среднее и медиану.
#     - В ячейке типа markdown опишите, сколько обычно занимает продажа. Какие продажи можно считать быстрыми, а какие — необычно долгими?"
# - [x]  выполнено задание: "Какие факторы больше всего влияют на общую (полную) стоимость объекта? Постройте графики, которые покажут зависимость цены от указанных ниже параметров. Для подготовки данных перед визуализацией вы можете использовать сводные таблицы."
#         - общей площади;
#         - жилой площади;
#         - площади кухни;
#         - количество комнат;
#         - типа этажа, на котором расположена квартира (первый, последний, другой);
#         - даты размещения (день недели, месяц, год);
# - [x]  выполнено задание: "Посчитайте среднюю цену одного квадратного метра в 10 населённых пунктах с наибольшим числом объявлений. Выделите населённые пункты с самой высокой и низкой стоимостью квадратного метра. Эти данные можно найти по имени в столбце `locality_name`."
# - [x]  выполнено задание: "Ранее вы посчитали расстояние до центра в километрах. Теперь выделите квартиры в Санкт-Петербурге с помощью столбца `locality_name` и вычислите среднюю цену каждого километра. Опишите, как стоимость объектов зависит от расстояния до центра города."
# - [x]  в каждом этапе есть промежуточные выводы
# - [x]  есть общий вывод
